# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

# %% [markdown]
# # DATA IMPORTED

# %%
country_data = pd.read_csv('country_data.csv',index_col=0)
country_data
# Out:
#            COUNTRY  YEAR  CASSAVA    MAIZE  PLANTAINS AND OTHERS  POTATOES  \
# 0      Afghanistan  1961      NaN  14000.0                   NaN   86667.0
# 1      Afghanistan  1962      NaN  14000.0                   NaN   76667.0
# 2      Afghanistan  1963      NaN  14260.0                   NaN   81333.0
# 3      Afghanistan  1964      NaN  14257.0                   NaN   86000.0
# 4      Afghanistan  1965      NaN  14400.0                   NaN   88000.0
# ...            ...   ...      ...      ...                   ...       ...
# 12762     Zimbabwe  2009  44708.0   4642.0                   NaN  166136.0
# 12763     Zimbabwe  2010  45152.0   8751.0                   NaN  166825.0
# 12764     Zimbabwe  2011  45589.0   6568.0                   NaN  167336.0
# 12765     Zimbabwe  2012  47010.0   7912.0                   NaN  171875.0
# 12766     Zimbabwe  2013  46000.0   7449.0                   NaN  165714.0
#
# ...

# %%
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## COUNTRY TEMPERATURES

# %%
country_temperatures = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='AVG_TEMP')
country_temperatures
# Out:
# COUNTRY  Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  Australia  \
# YEAR
# 1961           14.23    16.19    17.49   23.75     17.365      NaN  16.241667
# 1962           14.10    15.99    16.50   23.78     16.940      NaN  15.996667
# 1963           15.01    16.06    16.43   24.11     17.265      NaN  16.088333
# 1964           13.73    15.47    16.77   23.69     16.740      NaN  15.651667
# 1965           13.90    15.31    16.55   23.62     17.500      NaN  16.046667
# 1966           14.39    16.00    16.79   23.98     17.070      NaN  15.600000
# 1967           13.84    15.55    16.78   23.65     17.425      NaN  16.060000
# 1968           13.85    15.71    16.87   23.49     17.520      NaN  15.920000
# 1969           14.45    15.72    16.23   24.01     17.890      NaN  16.031667
# 1970           15.22    15.67    16.53   23.92     17.790      NaN  15.735000
# 1971           15.10    15.45    16.17   23.67     17.240      NaN  15.768333
# ...

# %% [markdown]
# ## CASSAVA

# %%
country_CASSAVA = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='CASSAVA')
country_CASSAVA
# Out:
# COUNTRY    Angola  Argentina   Bahamas    Brazil  Burkina Faso  Burundi  \
# YEAR
# 1961      35714.0   125810.0   83333.0  130732.0       60000.0  90244.0
# 1962      31875.0   121543.0   80645.0  134422.0       54000.0  90244.0
# 1963      32500.0   121185.0   84615.0  137523.0       52000.0  90244.0
# 1964      33000.0   115481.0   89552.0  141944.0       50000.0  90698.0
# 1965      33333.0   111282.0   92857.0  142818.0       52000.0  90698.0
# 1966      33333.0   115625.0   97222.0  138836.0       54000.0  90698.0
# 1967      33889.0   119134.0  100000.0  142434.0       60000.0  90909.0
# 1968      34333.0   110449.0  102564.0  146148.0       60000.0  90909.0
# 1969      35333.0   118815.0  106250.0  148193.0       60000.0  90909.0
# 1970      35556.0   112674.0  109756.0  145534.0       60000.0  90317.0
# 1971      35556.0   115234.0  113095.0  145945.0       60000.0  90106.0
# 1972      35556.0   100578.0  117647.0  145318.0       60000.0  89632.0
# ...

# %%
country_CASSAVA_sample = country_CASSAVA.sample(n=5,axis='columns')
country_CASSAVA_TEMP_sample = country_CASSAVA_sample.columns.intersection(country_temperatures.columns)
country_CASSAVA_TEMP_sample = country_temperatures[country_CASSAVA_TEMP_sample]
country_CASSAVA_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_CASSAVA_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## MAIZE

# %%
country_MAIZE = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='MAIZE')
country_MAIZE
# Out:
# COUNTRY  Afghanistan  Albania  Algeria  Angola  Argentina  Armenia  Australia  \
# YEAR
# 1961         14000.0   9541.0   9746.0  8113.0    17672.0      NaN    21213.0
# 1962         14000.0   9079.0   5400.0  8113.0    18936.0      NaN    21785.0
# 1963         14260.0  11924.0  10716.0  7692.0    16481.0      NaN    22343.0
# 1964         14257.0  11634.0  11703.0  8654.0    18010.0      NaN    19646.0
# 1965         14400.0  10509.0  11000.0  9375.0    16785.0      NaN    20336.0
# 1966         14400.0  15051.0   8190.0  7917.0    21499.0      NaN    15694.0
# 1967         14144.0  17241.0  10948.0  7600.0    24663.0      NaN    23347.0
# 1968         17064.0  18782.0  11443.0  7827.0    19421.0      NaN    22338.0
# 1969         17177.0  19485.0   9985.0  9000.0    19291.0      NaN    22401.0
# 1970         14757.0  20718.0  10235.0  9120.0    23299.0      NaN    24069.0
# 1971         13400.0  19443.0   8135.0  7776.0    24422.0      NaN    24756.0
# ...

# %%
country_MAIZE_sample = country_MAIZE.sample(n=5,axis='columns')
country_MAIZE_TEMP_sample = country_MAIZE_sample.columns.intersection(country_temperatures.columns)
country_MAIZE_TEMP_sample = country_temperatures[country_MAIZE_TEMP_sample]
country_MAIZE_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_MAIZE_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## 	PLANTAINS AND OTHERS

# %%
country_PLANTAINS = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='PLANTAINS AND OTHERS')
country_PLANTAINS
# Out:
# COUNTRY  Bahamas  Cameroon  Central African Republic  Colombia    Congo  \
# YEAR
# 1961         NaN   55242.0                   26667.0   68036.0  67500.0
# 1962         NaN   55105.0                   26667.0   68288.0  67500.0
# 1963         NaN   58026.0                   26667.0   68319.0  70000.0
# 1964         NaN   58112.0                   27222.0   68369.0  70000.0
# 1965         NaN   55221.0                   27222.0   81167.0  70000.0
# 1966         NaN   57270.0                   24500.0   63258.0  64444.0
# 1967         NaN   57042.0                   25000.0   69148.0  64444.0
# 1968         NaN   50796.0                   25500.0   69565.0  64444.0
# 1969         NaN   41365.0                   26000.0   68750.0  64444.0
# 1970         NaN   40580.0                   26500.0   70417.0  64444.0
# 1971         NaN   41307.0                   27000.0   46701.0  64444.0
# 1972         NaN   50144.0                   27500.0   48100.0  64000.0
# ...

# %%
country_PLANTAINS_sample = country_PLANTAINS.sample(n=5,axis='columns')
country_PLANTAINS_TEMP_sample = country_PLANTAINS_sample.columns.intersection(country_temperatures.columns)
country_PLANTAINS_TEMP_sample = country_temperatures[country_PLANTAINS_TEMP_sample]
country_PLANTAINS_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_PLANTAINS_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## 	POTATOES

# %%
country_POTATOES = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='POTATOES')
country_POTATOES
# Out:
# COUNTRY  Afghanistan   Albania   Algeria   Angola  Argentina   Armenia  \
# YEAR
# 1961         86667.0   72134.0  106217.0  50000.0   102110.0       NaN
# 1962         76667.0   54341.0  100000.0  50000.0    82576.0       NaN
# 1963         81333.0   76758.0   92466.0  53191.0    87699.0       NaN
# 1964         86000.0   90389.0   70342.0  58824.0    83457.0       NaN
# 1965         88000.0   57544.0   81919.0  57034.0   122170.0       NaN
# 1966         90667.0   87322.0   66768.0  57034.0    90025.0       NaN
# 1967         98000.0   72367.0   63501.0  58935.0   110138.0       NaN
# 1968        100000.0   72483.0   68023.0  60837.0    98431.0       NaN
# 1969        101987.0   55738.0   52466.0  62963.0   115387.0       NaN
# 1970         95364.0   54693.0   62542.0  62963.0   123156.0       NaN
# 1971        111333.0   63302.0   62150.0  62963.0   109653.0       NaN
# 1972        103947.0   53203.0   53450.0  62963.0    91093.0       NaN
# ...

# %%
country_POTATOES_sample = country_POTATOES.sample(n=5,axis='columns')
country_POTATOES_TEMP_sample = country_POTATOES_sample.columns.intersection(country_temperatures.columns)
country_POTATOES_TEMP_sample = country_temperatures[country_POTATOES_TEMP_sample]
country_POTATOES_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_POTATOES_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## RICE, PADDY

# %%
country_RICE = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='RICE, PADDY')
country_RICE
# Out:
# COUNTRY  Afghanistan  Albania  Algeria   Angola  Argentina  Australia  \
# YEAR
# 1961         15190.0  15514.0  45512.0  11600.0    32391.0    59000.0
# 1962         15190.0  16675.0  40000.0  12105.0    34357.0    68443.0
# 1963         15190.0  23599.0  44041.0  12500.0    34073.0    62981.0
# 1964         17273.0  23094.0  38275.0  13000.0    35172.0    60737.0
# 1965         17273.0  25998.0  29105.0  13913.0    39423.0    63365.0
# 1966         15180.0  27363.0  28906.0  13636.0    35324.0    71755.0
# 1967         19223.0  27912.0  26655.0  14865.0    35096.0    74074.0
# 1968         19515.0  30831.0  31333.0   6885.0    39958.0    74175.0
# 1969         19757.0  32698.0  34066.0  10630.0    39429.0    79238.0
# 1970         18119.0  29705.0  15810.0  11980.0    39941.0    62274.0
# 1971         17500.0  31573.0  23403.0  12632.0    37306.0    73918.0
# 1972         19048.0  30000.0  20729.0   9249.0    35379.0    61281.0
# ...

# %%
country_RICE_sample = country_RICE.sample(n=5,axis='columns')
country_RICE_TEMP_sample = country_RICE_sample.columns.intersection(country_temperatures.columns)
country_RICE_TEMP_sample = country_temperatures[country_RICE_TEMP_sample]
country_RICE_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_RICE_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## SORGHUM

# %%
country_SORGHUM = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='SORGHUM')
country_SORGHUM
# Out:
# COUNTRY  Albania   Algeria  Angola  Argentina  Australia  Austria  Azerbaijan  \
# YEAR
# 1961      5379.0    4526.0     NaN    18771.0    15807.0      NaN         NaN
# 1962      5672.0    6667.0     NaN    18559.0    17358.0      NaN         NaN
# 1963      6997.0    9511.0     NaN    14200.0    17618.0      NaN         NaN
# 1964      7635.0    7828.0     NaN    15110.0    14507.0      NaN         NaN
# 1965      7263.0    7669.0     NaN    12913.0    13935.0      NaN         NaN
# 1966      9173.0    7900.0     NaN    21243.0    11092.0      NaN         NaN
# 1967      9118.0    8506.0     NaN    15659.0    15680.0      NaN         NaN
# 1968     16505.0   10016.0     NaN    16059.0    15409.0      NaN         NaN
# 1969     11528.0    8830.0     NaN    17964.0    14042.0      NaN         NaN
# 1970     11554.0    8566.0     NaN    19277.0    15259.0      NaN         NaN
# 1971      9878.0    6979.0     NaN    20191.0    23513.0      NaN         NaN
# ...

# %%
country_SORGHUM_sample = country_SORGHUM.sample(n=5,axis='columns')
country_SORGHUM_TEMP_sample = country_SORGHUM_sample.columns.intersection(country_temperatures.columns)
country_SORGHUM_TEMP_sample = country_temperatures[country_SORGHUM_TEMP_sample]
country_SORGHUM_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_SORGHUM_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## SOYBEANS

# %%
country_SOYBEANS = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='SOYBEANS')
country_SOYBEANS
# Out:
# COUNTRY  Albania  Angola  Argentina  Australia  Austria  Azerbaijan  \
# YEAR
# 1961         NaN     NaN     9765.0     6667.0      NaN         NaN
# 1962         NaN     NaN    11628.0     7738.0      NaN         NaN
# 1963         NaN     NaN     9802.0     5978.0      NaN         NaN
# 1964         NaN     NaN    11457.0     4471.0      NaN         NaN
# 1965         NaN     NaN    10352.0     6053.0      NaN         NaN
# 1966         NaN     NaN    11600.0     3858.0      NaN         NaN
# 1967         NaN     NaN    11857.0     6635.0      NaN         NaN
# 1968         NaN     NaN    10891.0     5479.0      NaN         NaN
# 1969         NaN     NaN    11277.0     8313.0      NaN         NaN
# 1970         NaN     NaN    10320.0    10123.0      NaN         NaN
# 1971         NaN     NaN    16240.0    12568.0      NaN         NaN
# 1972         NaN     NaN    11471.0    18663.0      NaN         NaN
# 1973         NaN     NaN    17322.0    13567.0      NaN         NaN
# ...

# %%
country_SOYBEANS_sample = country_SOYBEANS.sample(n=5,axis='columns')
country_SOYBEANS_TEMP_sample = country_SOYBEANS_sample.columns.intersection(country_temperatures.columns)
country_SOYBEANS_TEMP_sample = country_temperatures[country_SOYBEANS_TEMP_sample]
country_SOYBEANS_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_SOYBEANS_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## SWEET POTATOES

# %%
country_SP = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='SWEET POTATOES')
country_SP
# Out:
# COUNTRY   Angola  Argentina  Australia  Bahamas   Bahrain  Bangladesh  \
# YEAR
# 1961     60000.0   102075.0    77344.0  22222.0  200000.0     89189.0
# 1962     66667.0    99964.0    92263.0  24615.0  200000.0     89744.0
# 1963     73529.0   100263.0    85700.0  26471.0  200000.0     90244.0
# 1964     77778.0    98705.0    93933.0  28571.0  200000.0     90909.0
# 1965     83333.0    94768.0    90693.0  30137.0  200000.0     95652.0
# 1966     78125.0   100025.0    86687.0  30667.0  200000.0    102948.0
# 1967     85294.0   105889.0    63951.0  30921.0  200000.0    124872.0
# 1968     82353.0    91385.0    60080.0  31579.0  200000.0    115569.0
# 1969     85294.0   105358.0    59429.0  31818.0  200000.0    115183.0
# 1970     81667.0    99095.0    56807.0  32468.0  200000.0    117135.0
# 1971     83333.0   108000.0    55283.0  32692.0  200000.0    114374.0
# 1972     86111.0   107340.0    94310.0  33333.0  200000.0    111124.0
# ...

# %%
country_SP_sample = country_SP.sample(n=5,axis='columns')
country_SP_TEMP_sample = country_SP_sample.columns.intersection(country_temperatures.columns)
country_SP_TEMP_sample = country_temperatures[country_SP_TEMP_sample]
country_SP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_SP_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## WHEAT

# %%
country_WHEAT = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='WHEAT')
country_WHEAT
# Out:
# COUNTRY  Afghanistan  Albania  Algeria   Angola  Argentina  Armenia  \
# YEAR
# 1961         10220.0   7731.0   4060.0  11111.0    12950.0      NaN
# 1962          9735.0  10522.0   8045.0  11111.0    15222.0      NaN
# 1963          8317.0   7127.0   8326.0  11111.0    15751.0      NaN
# 1964          9510.0   9625.0   5317.0   9286.0    18353.0      NaN
# 1965          9723.0  11344.0   6057.0  11111.0    13212.0      NaN
# 1966          8666.0  12398.0   4252.0  11000.0    11982.0      NaN
# 1967         11232.0  13550.0   6333.0  13500.0    12595.0      NaN
# 1968         11562.0  14124.0   6899.0  13500.0     9833.0      NaN
# 1969         11855.0  16389.0   6034.0   9430.0    13523.0      NaN
# 1970          9563.0  15377.0   6245.0   8546.0    13294.0      NaN
# 1971          8149.0  18735.0   6133.0   9130.0    12667.0      NaN
# 1972          8457.0  19000.0   6701.0  11592.0    15911.0      NaN
# 1973         11739.0  20097.0   4934.0   8867.0    16574.0      NaN
# ...

# %%
country_WHEAT_sample = country_WHEAT.sample(n=5,axis='columns')
country_WHEAT_TEMP_sample = country_WHEAT_sample.columns.intersection(country_temperatures.columns)
country_WHEAT_TEMP_sample = country_temperatures[country_WHEAT_TEMP_sample]
country_WHEAT_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_WHEAT_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %% [markdown]
# ## YAMS

# %%
country_YAMS = country_data.pivot_table(index='YEAR', columns='COUNTRY', values='YAMS')
country_YAMS
# Out:
# COUNTRY   Brazil  Burkina Faso  Burundi  Cameroon  Central African Republic  \
# YEAR
# 1961     89474.0       25734.0  57000.0   41667.0                   50000.0
# 1962     89796.0       25184.0  57000.0   41667.0                   54545.0
# 1963     90291.0       25287.0  57000.0   41111.0                   59091.0
# 1964     90741.0       40000.0  57000.0   41209.0                   54545.0
# 1965     90909.0       40000.0  57000.0   41821.0                   50000.0
# 1966     90517.0       48000.0  57000.0   41636.0                   53846.0
# 1967     90323.0       50000.0  57000.0   34731.0                   52000.0
# 1968     90551.0       44932.0  57000.0   34362.0                   52000.0
# 1969     90226.0       50000.0  57000.0   34527.0                   48000.0
# 1970     90511.0       58333.0  52727.0   36113.0                   50000.0
# 1971     90141.0       66667.0  53636.0   43896.0                   50000.0
# ...

# %%
country_YAMS_sample = country_YAMS.sample(n=5,axis='columns')
country_YAMS_TEMP_sample = country_YAMS_sample.columns.intersection(country_temperatures.columns)
country_YAMS_TEMP_sample = country_temperatures[country_YAMS_TEMP_sample]
country_YAMS_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Hectagrams per Hectare')
plt.show()
country_YAMS_TEMP_sample.plot(kind='line')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.ylabel('Average Temperature in Celsius')
plt.show()

# %%
print(country_data.columns)
# Out:
# Index(['COUNTRY', 'YEAR', 'CASSAVA', 'MAIZE', 'PLANTAINS AND OTHERS',
#        'POTATOES', 'RICE, PADDY', 'SORGHUM', 'SOYBEANS', 'SWEET POTATOES',
#        'WHEAT', 'YAMS', 'AVG_TEMP'],
#       dtype='object')

# %% [markdown]
# # TEMPERATURE
